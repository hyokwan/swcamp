# %% [markdown]
# # 라이브러리 선언

# %%
import pandas as pd

# %% [markdown]
# ### 1. 데이터 불러오기

# %%
pirLink = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002554243&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%AC_%EC%A7%80%EC%97%AD%EB%B3%84%20PIR%20%EB%B0%8F%20LIR_20211231"

# %%
indata = pd.read_csv(pirLink, encoding="ms949")

# %%
indata.tail(3)
# Out:
#        연도   월  전국소득대비 주택가격 비율  서울소득대비 주택가격 비율  부산소득대비 주택가격 비율  대구소득대비 주택가격 비율  \
# 210  2021   9            6.70            8.76            7.75            6.99
# 211  2021  10            6.69            8.55            6.91            7.67
# 212  2021  11            7.10            0.00           10.75           15.29
#
#      인천소득대비 주택가격 비율  광주소득대비 주택가격 비율  대전소득대비 주택가격 비율  울산소득대비 주택가격 비율  ...  \
# 210            7.83            6.56            7.14            6.08  ...
# 211            8.92            7.17            6.72            6.65  ...
# 212           12.03            7.47            7.11            7.42  ...
#
#      세종 평균 연소득 대비 평균 대출금액  경기 평균 연소득 대비 평균 대출금액  강원 평균 연소득 대비 평균 대출금액  \
# 210                  4.11                  4.27                  2.79
# 211                  4.85                  4.53                  2.98
# 212                  0.00                  4.36                  2.28
#
#      충북 평균 연소득 대비 평균 대출금액  충남 평균 연소득 대비 평균 대출금액  전북 평균 연소득 대비 평균 대출금액  \
# 210                  2.72                  3.15                  2.96
# 211                  2.58                  2.99                  2.71
# 212                  1.71                  3.89                  1.89
#
#      전남평균 연소득 대비 평균 대출금액  경북 평균 연소득 대비 평균 대출금액  경남 평균 연소득 대비 평균 대출금액  \
# 210                 3.52                  2.88                  3.06
# 211                 3.11                  2.87                  2.98
# 212                 2.69                  3.47                  3.65
#
#      제주 평균 연소득 대비 평균 대출금액
# 210                  3.86
# 211                  4.59
# 212                  6.62
#
# [3 rows x 38 columns]

# %% [markdown]
# ### 2. github데이터 불러오기

# %%
csDataUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/customerdata.csv"

# %%
customerData = pd.read_csv(csDataUrl)

# %% [markdown]
# ### 3. 클립보드 데이터 불러오기

# %%
myclipData = pd.read_clipboard()

# %%
myclipData.to_csv("d:aa.csv",encoding="ms949")

# %% [markdown]
# ### 4. 데이터베이스 (psycopg2) 데이터 불러오기

# %%
# postgresql접속용 라이브러리
# oracle(cxOracle), mariadb
import psycopg2
# 데이터 처리용 라이브러리
import pandas as pd
# 데이터베이스 접속 엔진 생성용 라이브러리
from sqlalchemy import create_engine 

# 데이터베이스 접속 엔진 생성
engine_pg = create_engine('postgresql://kopo:kopo@139.150.80.154:5432/kopo')

# %%
targetTable = "kopo_product_volume"

selloutData = pd.read_sql_table(table_name=targetTable, 
                  con=engine_pg)

engine_pg.table_names()
# Out:
# C:\Users\kopo\AppData\Local\Temp/ipykernel_14192/1498497353.py:6: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine_pg.table_names()
# ['kopo_product_volume', 'kopo_product_utf8', 'employee', 'employee2']

# %%
type(selloutData)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 
# 8                 8287           323148                8744           299553
# 9                 3353           169697                3523           158212
# 10                3412           133879                3499           127418
# 11                3051           157628                3269           152419
# 12                2216            98132                2352            93835
# 13                2206           116506                2325           105769
# 14                3251           157999                3194           156598
# 15                3663            98014                3633            94534
# 16                4671           221667                5085           189347
#
#     2022-05(중위단위당매매가격)  2022-06(평균매매가격)  2022-06(평균단위당매매가격)  2022-06(중위매매가격)  \
# 0                 5212           217133                5466           197697
# 1                 5704           232453                5987           210604
# 2                 3178           153816                3311           144353
# 3                 7367           263804                7566           245944
# 4                 7979           322820                8404           320429
# 5                 5566           171430                5888           167811
# 6                 7312           237062                7617           210606
# 7                 7195           248563                7082           228963
# 8                 8338           324079                8770           300104
# 9                 3353           169593                3519           158212
# 10                3412           133646                3493           127265
# 11                3048           157468                3265           152533
# 12                2225            98151                2348            93954
# 13                2200           116478                2324           105769
# 14                3251           157947                3193           156598
# 15                3663            98014                3633            94534
# 16                4685           221856                5090           189503
#
#     2022-06(중위단위당매매가격)
# 0                 5222
# 1                 5716
# 2                 3176
# 3                 7384
# 4                 8000
# 5                 5566
# 6                 7361
# 7                 7189
# 8                 8376
# 9                 3353
# 10                3400
# 11                3039
# 12                2219
# 13                2195
# 14                3251
# 15                3663
# 16                4700
#
# [17 rows x 97 columns]

# %% [markdown]
# ### 3. json api 데이터 불러오기

# %%
testData = [ {"TBL_NM": "ABC", "PRD_DE" : "202001"}]

# %%
# JSON string:
# Multi-line string
x = """
    {"TBL_NM": "ABC", "PRD_DE" : "50"}
    """
  
# parse x:
y = json.loads(x)

# %%
testString ='[{"TBL_NM": "ABC", "PRD_DE" : "50"},\
            {"TBL_NM": "ABC", "PRD_DE" : "60"} ]'
    
# Convert string to Python dict 
employee_dict = json.loads(employee) 
pd.DataFrame(employee_dict)
# Out:
#   TBL_NM PRD_DE
# 0    ABC     50
# 1    ABC     60

# %%
json.load(testData)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14192/3286037164.py in <module>
# ----> 1 json.load(testData)
#
# ~\anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'list' object has no attribute 'read'

# %%
pd.read_json(testData)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14192/101405075.py in <module>
# ----> 1 pd.read_json(testData)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     588         convert_axes = True
#     589
# --> 590     json_reader = JsonReader(
#     591         path_or_buf,
#     592         orient=orient,
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)
#     673                 raise ValueError("nrows can only be passed if lines=True")
#     674
# --> 675         data = self._get_data_from_filepath(filepath_or_buffer)
#     676         self.data = self._preprocess_data(data)
#     677
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     710             or file_exists(filepath_or_buffer)
#     711         ):
# --> 712             self.handles = get_handle(
#     713                 filepath_or_buffer,
#     714                 "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     607
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#     611         encoding=encoding,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     394     if not is_file_like(filepath_or_buffer):
#     395         msg = f"Invalid file path or buffer object type: {type(filepath_or_buffer)}"
# --> 396         raise ValueError(msg)
#     397
#     398     return IOArgs(
#
# ValueError: Invalid file path or buffer object type: <class 'list'>

# %%
# import json

# %%
# json.load((testData)

# %%
# pd.read_json(testData)

# %%
jsonAddress = "https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=MjUzMTdiMjcyZjQwY2VkMWJkY2RkYTRmZDkwMWQ3ZGY=&itmId=T20+T21+T22+&objL1=00+11+26+27+28+29+30+31+36+41+42+43+44+45+46+47+48+50+&objL2=&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=M&newEstPrdCnt=3&orgId=101&tblId=DT_1B040A3"

# %%
indata = pd.read_json(jsonAddress)
indata
# Out:
#                 TBL_NM  PRD_DE      TBL_ID ITM_NM        ITM_NM_ENG ITM_ID  \
# 0    행정구역(시군구)별 성별 인구수  202210  DT_1B040A3   총인구수   Koreans (Total)    T20
# 1    행정구역(시군구)별 성별 인구수  202211  DT_1B040A3   총인구수   Koreans (Total)    T20
# 2    행정구역(시군구)별 성별 인구수  202212  DT_1B040A3   총인구수   Koreans (Total)    T20
# 3    행정구역(시군구)별 성별 인구수  202210  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 4    행정구역(시군구)별 성별 인구수  202211  DT_1B040A3  남자인구수    Koreans (Male)    T21
# ..                 ...     ...         ...    ...               ...    ...
# 157  행정구역(시군구)별 성별 인구수  202211  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 158  행정구역(시군구)별 성별 인구수  202212  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 159  행정구역(시군구)별 성별 인구수  202210  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 160  행정구역(시군구)별 성별 인구수  202211  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 161  행정구역(시군구)별 성별 인구수  202212  DT_1B040A3  여자인구수  Koreans (Female)    T22
#
#     UNIT_NM  ORG_ID UNIT_NM_ENG   C1_OBJ_NM               C1_OBJ_NM_ENG  \
# 0         명     101      Person  행정구역(시군구)별  By Administrative District
# 1         명     101      Person  행정구역(시군구)별  By Administrative District
# 2         명     101      Person  행정구역(시군구)별  By Administrative District
# 3         명     101      Person  행정구역(시군구)별  By Administrative District
# 4         명     101      Person  행정구역(시군구)별  By Administrative District
# ..      ...     ...         ...         ...                         ...
# 157       명     101      Person  행정구역(시군구)별  By Administrative District
# 158       명     101      Person  행정구역(시군구)별  By Administrative District
# 159       명     101      Person  행정구역(시군구)별  By Administrative District
# 160       명     101      Person  행정구역(시군구)별  By Administrative District
# 161       명     101      Person  행정구역(시군구)별  By Administrative District
#
#            DT PRD_SE  C1    C1_NM      C1_NM_ENG
# 0    51459626      M   0       전국  Whole country
# 1    51450829      M   0       전국  Whole country
# 2    51439038      M   0       전국  Whole country
# 3    25649509      M   0       전국  Whole country
# 4    25643889      M   0       전국  Whole country
# ..        ...    ...  ..      ...            ...
# 157    339758      M  50  제주특별자치도        Jeju-do
# 158    339590      M  50  제주특별자치도        Jeju-do
# 159    338593      M  50  제주특별자치도        Jeju-do
# 160    338615      M  50  제주특별자치도        Jeju-do
# 161    338569      M  50  제주특별자치도        Jeju-do
#
# [162 rows x 16 columns]
